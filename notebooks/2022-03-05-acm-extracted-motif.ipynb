# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

# %%
# !ls ../data/intermediate
# Out:
# 2022-02-21-motif
# 2022-02-26-motif-consolidated.parquet
# 2022-02-26-motif-triplets-1e+03.parquet
# 2022-02-26-motif-triplets-1e+05.parquet
# 2022-03-02-extracted-triplets
# 2022-03-05-motif-triplets-1e+05
# checkpoint
# tb_logs

# %%
from pathlib import Path
import numpy as np
import IPython.display as ipd
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_parquet("../data/intermediate/2022-02-26-motif-triplets-1e+05.parquet")
tiles = Path("../data/intermediate/2022-03-05-motif-triplets-1e+05")

# %%
y = np.load(list(tiles.glob("*-1*.npy"))[0])
y.shape
sr = 32000

# %%
z = y
plt.plot(z)
plt.show()
ipd.Audio(z, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
z = y + np.random.rand(*y.shape) * 0.1
plt.plot(z)
plt.show()
ipd.Audio(z, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., -0.00320754,
#        -0.00170637, -0.00541193], dtype=float32)
