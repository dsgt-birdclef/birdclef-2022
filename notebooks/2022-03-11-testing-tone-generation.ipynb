# %% [markdown]
# # testing tone generation
#
# Exploratory work around testing loading audio properly.

# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

sr = 32000
y = librosa.tone(440, sr=sr, duration=3)
y.shape
# Out:
# (96000,)

# %%
plt.plot(y[:300])

# %%
plt.plot(np.abs(y[:300]))

# %%
y = np.ones(100) * 1.0
y.shape
# Out:
# (100,)

# %%
y[y == 1].sum()
# Out:
# 100.0

# %%
y[y == 0].sum()
# Out:
# 0.0

# %%
y = np.zeros(100)
(y == 0).sum()
# Out:
# 100
