# %%
import sys
import numpy as np
import pandas as pd
import pickle
import json
import torch
from pathlib import Path
from sklearn.preprocessing import LabelEncoder
from birdclef.datasets import soundscape
from birdclef.models.classifier import datasets
from birdclef.models.classifier import model as classifier_model
from birdclef.models.classifier_nn.datasets import ClassifierDataModule, ToEmbedSpace
from birdclef.models.classifier_nn.model import ClassifierNet
from birdclef.utils import chunks, transform_input

# %%
def generate_test_df(species):
    audio_root = "../data/raw/birdclef-2022/train_audio"
    filter_set = "../data/raw/birdclef-2022/scored_birds.json"
    scored_birds = json.loads(Path(filter_set).read_text())
    paths = list((Path(audio_root) / species).glob("*"))
    frames = []
    for path in paths:
        df = soundscape.parse_soundscape(path)
        frames.append(df[df.end_time != 0][["file_id", "end_time"]])
    test_df = pd.concat(frames).merge(
        pd.DataFrame(scored_birds, columns=["bird"]), how="cross"
    )
    test_df["row_id"] = (
        test_df["file_id"] + "_" + test_df["bird"] + "_" + test_df["end_time"].map(str)
    )
    return test_df

# %%
def test_df_with_true_label(species):
    test_df = generate_test_df(species)
    test_df["label"] = test_df["bird"] == species
    return test_df

# %% [markdown]
# ### Test for original classifier

# %%
def predict(species, classifier_source):
    audio_root = "../data/raw/birdclef-2022/train_audio"

    classifier_source = Path(classifier_source)
    with open(classifier_source / "submit_classifier.pkl", "rb") as fp:
        cls_model = pickle.load(fp)

    metadata = json.loads((classifier_source / "metadata.json").read_text())
    print(metadata)
    model, device = datasets.load_embedding_model(
        classifier_source / "embedding.ckpt", metadata["embedding_dim"]
    )

    use_ref_motif = metadata.get("use_ref_motif", False)
    if use_ref_motif:
        ref_motif_df = datasets.load_ref_motif(
            classifier_source / "reference_motifs", cens_sr=metadata["cens_sr"]
        )

    test_df = test_df_with_true_label(species)

    res = []
    paths = list((Path(audio_root) / species).glob("*"))[:10]
    # we only use the first 10 audios of each species for testing
    for path in paths:
        df = soundscape.parse_soundscape(path)
        if not df.empty:
            X_raw = np.stack(df.x.values)
            X = np.hstack(
                [transform_input(model, device, X_raw)]
                + (
                    datasets.transform_input_motif(
                        ref_motif_df,
                        X_raw,
                        cens_sr=metadata["cens_sr"],
                        mp_window=metadata["mp_window"],
                    )
                    if use_ref_motif
                    else []
                )
            )
            y_pred = cls_model.classifier.predict(X)
            res_inner = []
            for row, pred in zip(df.itertuples(), y_pred):
                labels = cls_model.label_encoder.inverse_transform(np.flatnonzero(pred))
                for label in labels:
                    res_inner.append(
                        {
                            "file_id": row.file_id,
                            "bird": label,
                            "end_time": row.end_time,
                            "target": True,
                        }
                    )
            res.append(pd.DataFrame(res_inner))
    res_df = pd.concat(res)
    submission_df = test_df.merge(
        res_df[res_df.bird != "other"], on=["file_id", "bird", "end_time"], how="left"
    ).fillna(False)
    print(submission_df.head())
    return submission_df[["row_id", "bird", "label", "target"]]

# %%
filter_set = "../data/raw/birdclef-2022/scored_birds.json"
scored_birds = json.loads(Path(filter_set).read_text())
classifier_source = "../data/processed/model/2022-05-17-v7"
results = []
for species in scored_birds:
    results.append(predict(species, classifier_source))
# Out:
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.1888 seconds
# STFT filter created, time used = 0.0458 seconds
# Mel filter created, time used = 0.0458 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122399         5  akiapo  XC122399_akiapo_5   True   False
# 1  XC122399         5  aniani  XC122399_aniani_5  False   False
# 2  XC122399         5  apapan  XC122399_apapan_5  False   False
# 3  XC122399         5  barpet  XC122399_barpet_5  False   False
# 4  XC122399         5  crehon  XC122399_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.1596 seconds
# STFT filter created, time used = 0.0989 seconds
# Mel filter created, time used = 0.0994 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC174949         5  akiapo  XC174949_akiapo_5  False   False
# 1  XC174949         5  aniani  XC174949_aniani_5   True   False
# 2  XC174949         5  apapan  XC174949_apapan_5  False   False
# 3  XC174949         5  barpet  XC174949_barpet_5  False   False
# 4  XC174949         5  crehon  XC174949_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 0.9936 seconds
# STFT filter created, time used = 0.0389 seconds
# Mel filter created, time used = 0.0389 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC139974         5  akiapo  XC139974_akiapo_5  False   False
# 1  XC139974         5  aniani  XC139974_aniani_5  False   False
# 2  XC139974         5  apapan  XC139974_apapan_5   True   False
# 3  XC139974         5  barpet  XC139974_barpet_5  False   False
# 4  XC139974         5  crehon  XC139974_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.2385 seconds
# STFT filter created, time used = 0.0735 seconds
# Mel filter created, time used = 0.0735 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC189893         5  akiapo  XC189893_akiapo_5  False   False
# 1  XC189893         5  aniani  XC189893_aniani_5  False   False
# 2  XC189893         5  apapan  XC189893_apapan_5  False   False
# 3  XC189893         5  barpet  XC189893_barpet_5   True   False
# 4  XC189893         5  crehon  XC189893_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.0527 seconds
# STFT filter created, time used = 0.0547 seconds
# Mel filter created, time used = 0.0547 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122341         5  akiapo  XC122341_akiapo_5  False   False
# 1  XC122341         5  aniani  XC122341_aniani_5  False   False
# 2  XC122341         5  apapan  XC122341_apapan_5  False   False
# 3  XC122341         5  barpet  XC122341_barpet_5  False   False
# 4  XC122341         5  crehon  XC122341_crehon_5   True   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3948 seconds
# STFT filter created, time used = 0.1196 seconds
# Mel filter created, time used = 0.1202 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175246         5  akiapo  XC175246_akiapo_5  False   False
# 1  XC175246         5  aniani  XC175246_aniani_5  False   False
# 2  XC175246         5  apapan  XC175246_apapan_5  False   False
# 3  XC175246         5  barpet  XC175246_barpet_5  False   False
# 4  XC175246         5  crehon  XC175246_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.2716 seconds
# STFT filter created, time used = 0.0658 seconds
# Mel filter created, time used = 0.0658 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC210297         5  akiapo  XC210297_akiapo_5  False   False
# 1  XC210297         5  aniani  XC210297_aniani_5  False   False
# 2  XC210297         5  apapan  XC210297_apapan_5  False   False
# 3  XC210297         5  barpet  XC210297_barpet_5  False   False
# 4  XC210297         5  crehon  XC210297_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.1128 seconds
# STFT filter created, time used = 0.0825 seconds
# Mel filter created, time used = 0.0825 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175238         5  akiapo  XC175238_akiapo_5  False   False
# 1  XC175238         5  aniani  XC175238_aniani_5  False   False
# 2  XC175238         5  apapan  XC175238_apapan_5  False   False
# 3  XC175238         5  barpet  XC175238_barpet_5  False   False
# 4  XC175238         5  crehon  XC175238_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3296 seconds
# STFT filter created, time used = 0.0727 seconds
# Mel filter created, time used = 0.0728 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122132         5  akiapo  XC122132_akiapo_5  False   False
# 1  XC122132         5  aniani  XC122132_aniani_5  False   False
# 2  XC122132         5  apapan  XC122132_apapan_5  False   False
# 3  XC122132         5  barpet  XC122132_barpet_5  False   False
# 4  XC122132         5  crehon  XC122132_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.2804 seconds
# STFT filter created, time used = 0.0412 seconds
# Mel filter created, time used = 0.0412 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC210216         5  akiapo  XC210216_akiapo_5  False   False
# 1  XC210216         5  aniani  XC210216_aniani_5  False   False
# 2  XC210216         5  apapan  XC210216_apapan_5  False   False
# 3  XC210216         5  barpet  XC210216_barpet_5  False   False
# 4  XC210216         5  crehon  XC210216_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3162 seconds
# STFT filter created, time used = 0.0410 seconds
# Mel filter created, time used = 0.0410 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC124707         5  akiapo  XC124707_akiapo_5  False   False
# 1  XC124707         5  aniani  XC124707_aniani_5  False   False
# 2  XC124707         5  apapan  XC124707_apapan_5  False   False
# 3  XC124707         5  barpet  XC124707_barpet_5  False   False
# 4  XC124707         5  crehon  XC124707_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.1350 seconds
# STFT filter created, time used = 0.0781 seconds
# Mel filter created, time used = 0.0786 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC328230         5  akiapo  XC328230_akiapo_5  False   False
# 1  XC328230         5  aniani  XC328230_aniani_5  False   False
# 2  XC328230         5  apapan  XC328230_apapan_5  False   False
# 3  XC328230         5  barpet  XC328230_barpet_5  False   False
# 4  XC328230         5  crehon  XC328230_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3750 seconds
# STFT filter created, time used = 0.0914 seconds
# Mel filter created, time used = 0.0914 seconds
#    file_id  end_time    bird            row_id  label  target
# 0  XC11463         5  akiapo  XC11463_akiapo_5  False   False
# 1  XC11463         5  aniani  XC11463_aniani_5  False   False
# 2  XC11463         5  apapan  XC11463_apapan_5  False   False
# 3  XC11463         5  barpet  XC11463_barpet_5  False   False
# 4  XC11463         5  crehon  XC11463_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.2674 seconds
# STFT filter created, time used = 0.0586 seconds
# Mel filter created, time used = 0.0591 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC113329         5  akiapo  XC113329_akiapo_5  False   False
# 1  XC113329         5  aniani  XC113329_aniani_5  False   False
# 2  XC113329         5  apapan  XC113329_apapan_5  False   False
# 3  XC113329         5  barpet  XC113329_barpet_5  False   False
# 4  XC113329         5  crehon  XC113329_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3513 seconds
# STFT filter created, time used = 0.0940 seconds
# Mel filter created, time used = 0.0945 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122542         5  akiapo  XC122542_akiapo_5  False   False
# 1  XC122542         5  aniani  XC122542_aniani_5  False   False
# 2  XC122542         5  apapan  XC122542_apapan_5  False   False
# 3  XC122542         5  barpet  XC122542_barpet_5  False   False
# 4  XC122542         5  crehon  XC122542_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.6121 seconds
# STFT filter created, time used = 0.1097 seconds
# Mel filter created, time used = 0.1102 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC123887         5  akiapo  XC123887_akiapo_5  False   False
# 1  XC123887         5  aniani  XC123887_aniani_5  False   False
# 2  XC123887         5  apapan  XC123887_apapan_5  False   False
# 3  XC123887         5  barpet  XC123887_barpet_5  False   False
# 4  XC123887         5  crehon  XC123887_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.3944 seconds
# STFT filter created, time used = 0.1052 seconds
# Mel filter created, time used = 0.1057 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175493         5  akiapo  XC175493_akiapo_5  False   False
# 1  XC175493         5  aniani  XC175493_aniani_5  False   False
# 2  XC175493         5  apapan  XC175493_apapan_5  False   False
# 3  XC175493         5  barpet  XC175493_barpet_5  False   False
# 4  XC175493         5  crehon  XC175493_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.4218 seconds
# STFT filter created, time used = 0.0480 seconds
# Mel filter created, time used = 0.0480 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC144892         5  akiapo  XC144892_akiapo_5  False   False
# 1  XC144892         5  aniani  XC144892_aniani_5  False   False
# 2  XC144892         5  apapan  XC144892_apapan_5  False   False
# 3  XC144892         5  barpet  XC144892_barpet_5  False   False
# 4  XC144892         5  crehon  XC144892_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.4713 seconds
# STFT filter created, time used = 0.1167 seconds
# Mel filter created, time used = 0.1167 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC112425         5  akiapo  XC112425_akiapo_5  False   False
# 1  XC112425         5  aniani  XC112425_aniani_5  False   False
# 2  XC112425         5  apapan  XC112425_apapan_5  False   False
# 3  XC112425         5  barpet  XC112425_barpet_5  False   False
# 4  XC112425         5  crehon  XC112425_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.4408 seconds
# STFT filter created, time used = 0.0761 seconds
# Mel filter created, time used = 0.0764 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122061         5  akiapo  XC122061_akiapo_5  False   False
# 1  XC122061         5  aniani  XC122061_aniani_5  False   False
# 2  XC122061         5  apapan  XC122061_apapan_5  False   False
# 3  XC122061         5  barpet  XC122061_barpet_5  False   False
# 4  XC122061         5  crehon  XC122061_crehon_5  False   False
# {'embedding_source': 'data/intermediate/embedding/tile2vec-v5/version_10/checkpoints/epoch=2-step=5635.ckpt', 'embedding_dim': 512, 'created': '2022-05-17T22:00:49.874911', 'cens_sr': 10, 'mp_window': 20, 'use_ref_motif': False}
# STFT kernels created, time used = 1.2501 seconds
# STFT filter created, time used = 0.0507 seconds
# Mel filter created, time used = 0.0512 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC127471         5  akiapo  XC127471_akiapo_5  False   False
# 1  XC127471         5  aniani  XC127471_aniani_5  False   False
# 2  XC127471         5  apapan  XC127471_apapan_5  False   False
# 3  XC127471         5  barpet  XC127471_barpet_5  False   False
# 4  XC127471         5  crehon  XC127471_crehon_5  False   False

# %%
result = pd.concat(results)

# %%
result
# Out:
#                    row_id     bird  label  target
# 0       XC122399_akiapo_5   akiapo   True   False
# 1       XC122399_aniani_5   aniani  False   False
# 2       XC122399_apapan_5   apapan  False   False
# 3       XC122399_barpet_5   barpet  False   False
# 4       XC122399_crehon_5   crehon  False   False
# ...                   ...      ...    ...     ...
# 8962     XC667142_omao_30     omao  False   False
# 8963   XC667142_puaioh_30   puaioh  False   False
# 8964   XC667142_skylar_30   skylar  False   False
# 8965  XC667142_warwhe1_30  warwhe1  False   False
# 8966   XC667142_yefcan_30   yefcan   True   False
#
# [269094 rows x 4 columns]

# %%
f1_scores = []
for species in scored_birds:
    print("species:", species)
    if (
        result[
            (result["bird"] == species)
            & (result["label"] == True)
            & (result["target"] == True)
        ].shape[0]
        == 0
    ):
        precision = recall = f1_score = 0
    else:
        precision = result[
            (result["bird"] == species)
            & (result["label"] == True)
            & (result["target"] == True)
        ].shape[0] / (
            result[
                (result["bird"] == species)
                & (result["label"] == True)
                & (result["target"] == True)
            ].shape[0]
            + result[
                (result["bird"] == species)
                & (result["label"] == False)
                & (result["target"] == True)
            ].shape[0]
        )
        recall = result[
            (result["bird"] == species)
            & (result["label"] == True)
            & (result["target"] == True)
        ].shape[0] / (
            result[
                (result["bird"] == species)
                & (result["label"] == True)
                & (result["target"] == True)
            ].shape[0]
            + result[
                (result["bird"] == species)
                & (result["label"] == True)
                & (result["target"] == False)
            ].shape[0]
        )
        f1_score = 2 * (precision * recall) / (precision + recall)
    print("precision:", precision)
    print("recall:", recall)
    f1_scores.append(f1_score)
# Out:
# species: akiapo
# precision: 0
# recall: 0
# species: aniani
# precision: 0
# recall: 0
# species: apapan
# precision: 0
# recall: 0
# species: barpet
# precision: 0
# recall: 0
# species: crehon
# precision: 0.058823529411764705
# recall: 0.043478260869565216
# species: elepai
# precision: 0.07142857142857142
# recall: 0.007633587786259542
# species: ercfra
# precision: 0.07317073170731707
# recall: 0.2727272727272727
# species: hawama
# precision: 0
# recall: 0
# species: hawcre
# precision: 0
# recall: 0
# species: hawgoo
# precision: 0
# recall: 0
# species: hawhaw
# precision: 0
# recall: 0
# species: hawpet1
# precision: 0.05263157894736842
# recall: 0.125
# species: houfin
# precision: 0
# recall: 0
# species: iiwi
# precision: 0
# recall: 0
# species: jabwar
# precision: 0
# recall: 0
# species: maupar
# precision: 0
# recall: 0
# species: omao
# precision: 0
# recall: 0
# species: puaioh
# precision: 0.1
# recall: 0.14285714285714285
# species: skylar
# precision: 0
# recall: 0
# species: warwhe1
# precision: 0
# recall: 0
# species: yefcan
# precision: 0
# recall: 0

# %%
print("The macro f1-score of the classifier is:", np.mean(f1_scores))
# Out:
# The macro f1-score of the classifier is: 0.017661850082404514

# %% [markdown]
# ### Test for neural network classifier

# %%
def predict(species, classifier_source, method):
    audio_root = "../data/raw/birdclef-2022/train_audio"
    classifier_source = Path(classifier_source)

    filter_set = json.loads(
        Path("../data/raw/birdclef-2022/scored_birds.json").read_text()
    )
    label_encoder = LabelEncoder()
    label_encoder.fit(["noise"] + filter_set)

    metadata = json.loads((classifier_source / "metadata.json").read_text())

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    to_embed = ToEmbedSpace(
        classifier_source / "embedding.ckpt", z_dim=metadata["embedding_dim"]
    )
    model = ClassifierNet.load_from_checkpoint(
        classifier_source / "classify.ckpt",
        z_dim=metadata["embedding_dim"],
        n_classes=len(label_encoder.classes_),
    )

    test_df = test_df_with_true_label(species)

    res = []
    paths = list((Path(audio_root) / species).glob("*"))[:10]
    # we only use the first 10 audios of each species for testing
    for path in paths:
        df = soundscape.parse_soundscape(path)
        if not df.empty:
            X_raw = torch.from_numpy(np.stack(df.x.values)).float().to(device)
            X, _ = to_embed((X_raw, None))
            y_pred = model.to(device)(X).cpu().detach().numpy()
            # now convert the prediction to something that we can use
            res_inner = []
            for row, pred in zip(df.itertuples(), y_pred):
                labels = []
                sorted_indices = np.argsort(pred)[::-1]
                if method == "top":
                    labels = label_encoder.inverse_transform(sorted_indices[:1])
                elif method == "top-not-noise":
                    for label in label_encoder.inverse_transform(sorted_indices):
                        if label == "noise":
                            break
                        labels.append(label)
                for label in labels:
                    res_inner.append(
                        {
                            "file_id": row.file_id,
                            "bird": label,
                            "end_time": row.end_time,
                            "target": True,
                        }
                    )
            res.append(pd.DataFrame(res_inner))
    res_df = pd.concat(res)
    submission_df = test_df.merge(
        res_df[res_df.bird != "noise"], on=["file_id", "bird", "end_time"], how="left"
    ).fillna(False)
    print(submission_df.head())
    return submission_df[["row_id", "bird", "label", "target"]]

# %%
classifier_source = "../data/processed/classify-nn/0.13.0-202205222347"
results_nn = []
for species in scored_birds:
    results_nn.append(predict(species, classifier_source, method="top"))
# Out:
# STFT kernels created, time used = 1.3795 seconds
# STFT filter created, time used = 0.0768 seconds
# Mel filter created, time used = 0.0768 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122399         5  akiapo  XC122399_akiapo_5   True   False
# 1  XC122399         5  aniani  XC122399_aniani_5  False   False
# 2  XC122399         5  apapan  XC122399_apapan_5  False   False
# 3  XC122399         5  barpet  XC122399_barpet_5  False   False
# 4  XC122399         5  crehon  XC122399_crehon_5  False   False
# STFT kernels created, time used = 1.4959 seconds
# STFT filter created, time used = 0.0898 seconds
# Mel filter created, time used = 0.0904 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC174949         5  akiapo  XC174949_akiapo_5  False   False
# 1  XC174949         5  aniani  XC174949_aniani_5   True   False
# 2  XC174949         5  apapan  XC174949_apapan_5  False   False
# 3  XC174949         5  barpet  XC174949_barpet_5  False    True
# 4  XC174949         5  crehon  XC174949_crehon_5  False   False
# STFT kernels created, time used = 1.3040 seconds
# STFT filter created, time used = 0.0277 seconds
# Mel filter created, time used = 0.0277 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC139974         5  akiapo  XC139974_akiapo_5  False   False
# 1  XC139974         5  aniani  XC139974_aniani_5  False   False
# 2  XC139974         5  apapan  XC139974_apapan_5   True   False
# 3  XC139974         5  barpet  XC139974_barpet_5  False    True
# 4  XC139974         5  crehon  XC139974_crehon_5  False   False
# STFT kernels created, time used = 1.1868 seconds
# STFT filter created, time used = 0.0416 seconds
# Mel filter created, time used = 0.0416 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC189893         5  akiapo  XC189893_akiapo_5  False   False
# 1  XC189893         5  aniani  XC189893_aniani_5  False   False
# 2  XC189893         5  apapan  XC189893_apapan_5  False   False
# 3  XC189893         5  barpet  XC189893_barpet_5   True   False
# 4  XC189893         5  crehon  XC189893_crehon_5  False   False
# STFT kernels created, time used = 1.1666 seconds
# STFT filter created, time used = 0.0609 seconds
# Mel filter created, time used = 0.0609 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122341         5  akiapo  XC122341_akiapo_5  False   False
# 1  XC122341         5  aniani  XC122341_aniani_5  False    True
# 2  XC122341         5  apapan  XC122341_apapan_5  False   False
# 3  XC122341         5  barpet  XC122341_barpet_5  False   False
# 4  XC122341         5  crehon  XC122341_crehon_5   True   False
# STFT kernels created, time used = 1.5694 seconds
# STFT filter created, time used = 0.0481 seconds
# Mel filter created, time used = 0.0486 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175246         5  akiapo  XC175246_akiapo_5  False   False
# 1  XC175246         5  aniani  XC175246_aniani_5  False   False
# 2  XC175246         5  apapan  XC175246_apapan_5  False   False
# 3  XC175246         5  barpet  XC175246_barpet_5  False   False
# 4  XC175246         5  crehon  XC175246_crehon_5  False   False
# STFT kernels created, time used = 1.4447 seconds
# STFT filter created, time used = 0.0298 seconds
# Mel filter created, time used = 0.0303 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC210297         5  akiapo  XC210297_akiapo_5  False   False
# 1  XC210297         5  aniani  XC210297_aniani_5  False   False
# 2  XC210297         5  apapan  XC210297_apapan_5  False   False
# 3  XC210297         5  barpet  XC210297_barpet_5  False   False
# 4  XC210297         5  crehon  XC210297_crehon_5  False   False
# STFT kernels created, time used = 1.3852 seconds
# STFT filter created, time used = 0.0336 seconds
# Mel filter created, time used = 0.0336 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175238         5  akiapo  XC175238_akiapo_5  False   False
# 1  XC175238         5  aniani  XC175238_aniani_5  False   False
# 2  XC175238         5  apapan  XC175238_apapan_5  False   False
# 3  XC175238         5  barpet  XC175238_barpet_5  False   False
# 4  XC175238         5  crehon  XC175238_crehon_5  False   False
# STFT kernels created, time used = 1.4776 seconds
# STFT filter created, time used = 0.0768 seconds
# Mel filter created, time used = 0.0778 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122132         5  akiapo  XC122132_akiapo_5  False   False
# 1  XC122132         5  aniani  XC122132_aniani_5  False   False
# 2  XC122132         5  apapan  XC122132_apapan_5  False   False
# 3  XC122132         5  barpet  XC122132_barpet_5  False   False
# 4  XC122132         5  crehon  XC122132_crehon_5  False   False
# STFT kernels created, time used = 1.3542 seconds
# STFT filter created, time used = 0.0920 seconds
# Mel filter created, time used = 0.0920 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC210216         5  akiapo  XC210216_akiapo_5  False   False
# 1  XC210216         5  aniani  XC210216_aniani_5  False   False
# 2  XC210216         5  apapan  XC210216_apapan_5  False   False
# 3  XC210216         5  barpet  XC210216_barpet_5  False   False
# 4  XC210216         5  crehon  XC210216_crehon_5  False   False
# STFT kernels created, time used = 1.4245 seconds
# STFT filter created, time used = 0.0509 seconds
# Mel filter created, time used = 0.0509 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC124707         5  akiapo  XC124707_akiapo_5  False   False
# 1  XC124707         5  aniani  XC124707_aniani_5  False   False
# 2  XC124707         5  apapan  XC124707_apapan_5  False   False
# 3  XC124707         5  barpet  XC124707_barpet_5  False   False
# 4  XC124707         5  crehon  XC124707_crehon_5  False   False
# STFT kernels created, time used = 1.4347 seconds
# STFT filter created, time used = 0.0612 seconds
# Mel filter created, time used = 0.0612 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC328230         5  akiapo  XC328230_akiapo_5  False   False
# 1  XC328230         5  aniani  XC328230_aniani_5  False   False
# 2  XC328230         5  apapan  XC328230_apapan_5  False   False
# 3  XC328230         5  barpet  XC328230_barpet_5  False   False
# 4  XC328230         5  crehon  XC328230_crehon_5  False   False
# STFT kernels created, time used = 1.2712 seconds
# STFT filter created, time used = 0.0406 seconds
# Mel filter created, time used = 0.0406 seconds
#    file_id  end_time    bird            row_id  label  target
# 0  XC11463         5  akiapo  XC11463_akiapo_5  False   False
# 1  XC11463         5  aniani  XC11463_aniani_5  False   False
# 2  XC11463         5  apapan  XC11463_apapan_5  False   False
# 3  XC11463         5  barpet  XC11463_barpet_5  False   False
# 4  XC11463         5  crehon  XC11463_crehon_5  False   False
# STFT kernels created, time used = 1.2373 seconds
# STFT filter created, time used = 0.0492 seconds
# Mel filter created, time used = 0.0493 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC113329         5  akiapo  XC113329_akiapo_5  False   False
# 1  XC113329         5  aniani  XC113329_aniani_5  False   False
# 2  XC113329         5  apapan  XC113329_apapan_5  False   False
# 3  XC113329         5  barpet  XC113329_barpet_5  False   False
# 4  XC113329         5  crehon  XC113329_crehon_5  False   False
# STFT kernels created, time used = 1.3594 seconds
# STFT filter created, time used = 0.0737 seconds
# Mel filter created, time used = 0.0737 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122542         5  akiapo  XC122542_akiapo_5  False   False
# 1  XC122542         5  aniani  XC122542_aniani_5  False   False
# 2  XC122542         5  apapan  XC122542_apapan_5  False   False
# 3  XC122542         5  barpet  XC122542_barpet_5  False   False
# 4  XC122542         5  crehon  XC122542_crehon_5  False   False
# STFT kernels created, time used = 1.2622 seconds
# STFT filter created, time used = 0.0412 seconds
# Mel filter created, time used = 0.0412 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC123887         5  akiapo  XC123887_akiapo_5  False   False
# 1  XC123887         5  aniani  XC123887_aniani_5  False   False
# 2  XC123887         5  apapan  XC123887_apapan_5  False   False
# 3  XC123887         5  barpet  XC123887_barpet_5  False   False
# 4  XC123887         5  crehon  XC123887_crehon_5  False   False
# STFT kernels created, time used = 1.4199 seconds
# STFT filter created, time used = 0.0282 seconds
# Mel filter created, time used = 0.0282 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC175493         5  akiapo  XC175493_akiapo_5  False   False
# 1  XC175493         5  aniani  XC175493_aniani_5  False   False
# 2  XC175493         5  apapan  XC175493_apapan_5  False   False
# 3  XC175493         5  barpet  XC175493_barpet_5  False   False
# 4  XC175493         5  crehon  XC175493_crehon_5  False   False
# STFT kernels created, time used = 1.2356 seconds
# STFT filter created, time used = 0.0793 seconds
# Mel filter created, time used = 0.0797 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC144892         5  akiapo  XC144892_akiapo_5  False   False
# 1  XC144892         5  aniani  XC144892_aniani_5  False   False
# 2  XC144892         5  apapan  XC144892_apapan_5  False   False
# 3  XC144892         5  barpet  XC144892_barpet_5  False   False
# 4  XC144892         5  crehon  XC144892_crehon_5  False   False
# STFT kernels created, time used = 1.2370 seconds
# STFT filter created, time used = 0.0295 seconds
# Mel filter created, time used = 0.0295 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC112425         5  akiapo  XC112425_akiapo_5  False   False
# 1  XC112425         5  aniani  XC112425_aniani_5  False   False
# 2  XC112425         5  apapan  XC112425_apapan_5  False   False
# 3  XC112425         5  barpet  XC112425_barpet_5  False   False
# 4  XC112425         5  crehon  XC112425_crehon_5  False   False
# STFT kernels created, time used = 1.1732 seconds
# STFT filter created, time used = 0.0638 seconds
# Mel filter created, time used = 0.0638 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC122061         5  akiapo  XC122061_akiapo_5  False   False
# 1  XC122061         5  aniani  XC122061_aniani_5  False   False
# 2  XC122061         5  apapan  XC122061_apapan_5  False   False
# 3  XC122061         5  barpet  XC122061_barpet_5  False   False
# 4  XC122061         5  crehon  XC122061_crehon_5  False   False
# STFT kernels created, time used = 1.2879 seconds
# STFT filter created, time used = 0.0749 seconds
# Mel filter created, time used = 0.0759 seconds
#     file_id  end_time    bird             row_id  label  target
# 0  XC127471         5  akiapo  XC127471_akiapo_5  False   False
# 1  XC127471         5  aniani  XC127471_aniani_5  False   False
# 2  XC127471         5  apapan  XC127471_apapan_5  False   False
# 3  XC127471         5  barpet  XC127471_barpet_5  False   False
# 4  XC127471         5  crehon  XC127471_crehon_5  False   False

# %%
result_nn = pd.concat(results_nn)

# %%
f1_scores_nn = []
for species in scored_birds:
    print("species:", species)
    if (
        result_nn[
            (result_nn["bird"] == species)
            & (result_nn["label"] == True)
            & (result_nn["target"] == True)
        ].shape[0]
        == 0
    ):
        precision = recall = f1_score = 0
    else:
        precision = result_nn[
            (result_nn["bird"] == species)
            & (result_nn["label"] == True)
            & (result_nn["target"] == True)
        ].shape[0] / (
            result_nn[
                (result_nn["bird"] == species)
                & (result_nn["label"] == True)
                & (result_nn["target"] == True)
            ].shape[0]
            + result_nn[
                (result_nn["bird"] == species)
                & (result_nn["label"] == False)
                & (result_nn["target"] == True)
            ].shape[0]
        )
        recall = result_nn[
            (result_nn["bird"] == species)
            & (result_nn["label"] == True)
            & (result_nn["target"] == True)
        ].shape[0] / (
            result_nn[
                (result_nn["bird"] == species)
                & (result_nn["label"] == True)
                & (result_nn["target"] == True)
            ].shape[0]
            + result_nn[
                (result_nn["bird"] == species)
                & (result_nn["label"] == True)
                & (result_nn["target"] == False)
            ].shape[0]
        )
        f1_score = 2 * (precision * recall) / (precision + recall)
    print("precision:", precision)
    print("recall:", recall)
    f1_scores_nn.append(f1_score)
# Out:
# species: akiapo
# precision: 0.038461538461538464
# recall: 0.006896551724137931
# species: aniani
# precision: 0
# recall: 0
# species: apapan
# precision: 0.05263157894736842
# recall: 0.004056795131845842
# species: barpet
# precision: 0.05128205128205128
# recall: 0.03076923076923077
# species: crehon
# precision: 0
# recall: 0
# species: elepai
# precision: 0.09090909090909091
# recall: 0.007633587786259542
# species: ercfra
# precision: 0
# recall: 0
# species: hawama
# precision: 0.1111111111111111
# recall: 0.007142857142857143
# species: hawcre
# precision: 0.23214285714285715
# recall: 0.026859504132231406
# species: hawgoo
# precision: 0.09090909090909091
# recall: 0.024390243902439025
# species: hawhaw
# precision: 0.016129032258064516
# recall: 0.038461538461538464
# species: hawpet1
# precision: 0
# recall: 0
# species: houfin
# precision: 0.029411764705882353
# recall: 0.00030674846625766873
# species: iiwi
# precision: 0
# recall: 0
# species: jabwar
# precision: 0.07692307692307693
# recall: 0.0012453300124533001
# species: maupar
# precision: 0.051075268817204304
# recall: 0.3877551020408163
# species: omao
# precision: 0.10714285714285714
# recall: 0.013392857142857142
# species: puaioh
# precision: 0
# recall: 0
# species: skylar
# precision: 0.05263157894736842
# recall: 0.00018882175226586103
# species: warwhe1
# precision: 0
# recall: 0
# species: yefcan
# precision: 0.08333333333333333
# recall: 0.00234192037470726

# %%
print("The macro f1-score of the classifier is:", np.mean(f1_scores_nn))
# Out:
# The macro f1-score of the classifier is: 0.015075987634262983
